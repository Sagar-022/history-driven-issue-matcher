# %%
"""
Efficient GitHub analysis to identify issue solvers by starting with merged PRs
"""
import json
from datetime import datetime
from github import Github
import os



def map_prs_to_issues(repo, max_prs=500):
    """
    Start by retrieving merged PRs and mapping them to the issues they close.
    This is more efficient for large repositories.
    """
    # Get merged PRs
    merged_prs = repo.get_pulls(state='closed', sort='updated', direction='desc')

    # Track PR to issue mapping
    pr_issue_mapping = {}
    processed_count = 0

    for pr in merged_prs:
        try:
            # Skip if PR wasn't merged
            if not pr.merged:
                continue

            processed_count += 1

            # Extract PR info
            pr_info = {
                "number": pr.number,
                "title": pr.title,
                "author": pr.user.login,
                "merged_at": pr.merged_at.isoformat() if pr.merged_at else None,
                "merged_by": pr.merged_by.login if pr.merged_by else None,
                "referenced_issues": []
            }

            # Find issues referenced in PR body
            if pr.body:
                # Look for issue references using common patterns
                import re
                # Match patterns like "fixes #123", "closes #456", etc.
                closing_patterns = [
                    r'(?:close|closes|closed|fix|fixes|fixed|resolve|resolves|resolved)[\s:]+#(\d+)',
                    r'(?:issue|issues)[\s:]+#(\d+)'  # Also look for general issue references
                ]

                for pattern in closing_patterns:
                    matches = re.findall(pattern, pr.body.lower())
                    for match in matches:
                        issue_number = int(match)
                        pr_info["referenced_issues"].append(issue_number)

            # Store PR info if it references any issues
            if pr_info["referenced_issues"]:
                pr_issue_mapping[pr.number] = pr_info
                print(f"PR #{pr.number} references issues: {pr_info['referenced_issues']}")

            # Stop after processing max_prs
            if processed_count >= max_prs:
                break

        except Exception as e:
            print(f"Error processing PR #{pr.number}: {e}")
            continue

    # Save mapping to file
    with open('pr_issue_mapping.json', 'w') as f:
        json.dump(pr_issue_mapping, f, indent=2)

    print(f"Mapped {len(pr_issue_mapping)} PRs to their referenced issues")
    return pr_issue_mapping

def analyze_issue_solvers(repo, pr_issue_mapping=None):
    """
    Analyze PRs to determine who solved each issue and what files were changed.
    """
    # Load mapping from file if not provided
    if pr_issue_mapping is None:
        with open('pr_issue_mapping.json', 'r') as f:
            pr_issue_mapping = json.load(f)

    # Convert to issue-centric mapping
    issue_solver_data = {}

    # First, organize PRs by issue
    for pr_number, pr_data in pr_issue_mapping.items():
        pr_number = int(pr_number)  # Convert string keys back to integers

        for issue_number in pr_data["referenced_issues"]:
            # Initialize issue data if first encounter
            if issue_number not in issue_solver_data:
                issue_solver_data[issue_number] = {
                    "issue_number": issue_number,
                    "title": None,  # Will fill this later
                    "linked_prs": [],
                    "solvers": [],
                    "file_changes": []
                }

            # Add PR to issue data
            issue_solver_data[issue_number]["linked_prs"].append({
                "number": pr_number,
                "title": pr_data["title"],
                "merged_at": pr_data["merged_at"],
                "merged_by": pr_data["merged_by"]
            })

    # For each issue, get details and analyze PR contributors + file changes
    for issue_number in list(issue_solver_data.keys()):
        try:
            # Get issue details
            issue = repo.get_issue(issue_number)

            # Update issue info
            issue_solver_data[issue_number].update({
                "title": issue.title,
                "labels": [label.name for label in issue.labels],
                "state": issue.state,
                "created_at": issue.created_at.isoformat(),
                "closed_at": issue.closed_at.isoformat() if issue.closed_at else None,
                "opened_by": issue.user.login
            })

            # Get detailed PR info for each linked PR
            solvers = set()
            file_changes = []

            for pr_info in issue_solver_data[issue_number]["linked_prs"]:
                pr_number = pr_info["number"]
                try:
                    # Get full PR object
                    pr = repo.get_pull(pr_number)

                    # Get commit authors
                    pr_contributors = get_pr_contributors(pr)
                    solvers.update(pr_contributors)

                    # Get file changes
                    pr_file_changes = get_pr_file_changes(pr)
                    file_changes.extend(pr_file_changes)

                except Exception as e:
                    print(f"Error analyzing PR #{pr_number}: {e}")

            # Update solvers and file changes
            issue_solver_data[issue_number]["solvers"] = list(solvers)
            issue_solver_data[issue_number]["file_changes"] = file_changes

            print(f"Issue #{issue_number} ({issue.title}) was solved by: {', '.join(list(solvers)) if solvers else 'Unknown'}")

        except Exception as e:
            print(f"Error retrieving details for issue #{issue_number}: {e}")
            # Remove issues we couldn't get details for
            issue_solver_data.pop(issue_number, None)

    # Save solver data to file
    with open('issue_solver_data.json', 'w') as f:
        json.dump(issue_solver_data, f, indent=2)

    return issue_solver_data

def get_pr_contributors(pull_request):
    """Get primary contributors to a pull request (focus on commit authors)."""
    contributors = set()

    try:
        # Get commit authors - these are the people who actually wrote the code
        commits = pull_request.get_commits()
        for commit in commits:
            if commit.author:
                contributors.add(commit.author.login)
    except Exception as e:
        print(f"Error fetching commit authors for PR #{pull_request.number}: {e}")

    return list(contributors)

def get_pr_file_changes(pull_request):
    """Get information about files changed in a pull request."""
    try:
        files = pull_request.get_files()
        file_changes = []
        for file in files:
            file_changes.append({
                "filename": file.filename,
                "additions": file.additions,
                "deletions": file.deletions,
                "changes": file.changes,
                "status": file.status  # 'added', 'removed', 'modified', etc.
            })
        return file_changes
    except Exception as e:
        print(f"Error fetching file changes for PR #{pull_request.number}: {e}")
        return []

def generate_solver_stats(issue_solver_data=None):
    """Generate statistics about who solved issues."""
    # Load data from file if not provided
    if issue_solver_data is None:
        with open('issue_solver_data.json', 'r') as f:
            issue_solver_data = json.load(f)

    # Track solver statistics
    solver_stats = {}

    # For each issue, credit solvers
    for issue_number, issue_data in issue_solver_data.items():
        for solver in issue_data["solvers"]:
            if solver not in solver_stats:
                solver_stats[solver] = {
                    "issues_solved": 0,
                    "files_changed": set(),
                    "additions": 0,
                    "deletions": 0,
                    "total_changes": 0
                }

            # Increment issue count
            solver_stats[solver]["issues_solved"] += 1

            # Track files and changes
            for file_change in issue_data["file_changes"]:
                solver_stats[solver]["files_changed"].add(file_change["filename"])
                solver_stats[solver]["additions"] += file_change["additions"]
                solver_stats[solver]["deletions"] += file_change["deletions"]
                solver_stats[solver]["total_changes"] += file_change["changes"]

    # Convert sets to lists for JSON serialization
    for solver in solver_stats:
        solver_stats[solver]["files_changed"] = list(solver_stats[solver]["files_changed"])

    # Sort solvers by issues solved (descending)
    sorted_solvers = sorted(
        solver_stats.items(),
        key=lambda x: x[1]["issues_solved"],
        reverse=True
    )

    # Create formatted report
    solver_report = {
        "total_issues": len(issue_solver_data),
        "total_solvers": len(solver_stats),
        "solvers_by_issues": [
            {
                "solver": solver,
                "issues_solved": stats["issues_solved"],
                "files_changed": len(stats["files_changed"]),
                "total_changes": stats["total_changes"]
            }
            for solver, stats in sorted_solvers
        ],
        "detailed_stats": solver_stats
    }

    # Save report to file
    with open('solver_stats.json', 'w') as f:
        json.dump(solver_report, f, indent=2)

    print(f"Generated solver statistics for {len(solver_stats)} contributors")
    return solver_report


def retrieve_pr_file_contents(repo, pr_number, output_dir=None):
    """
    Retrieve the full content of all files changed in a specific PR and save them.

    Args:
        repo: GitHub repository object
        pr_number: Pull request number
        output_dir: Directory to save files (defaults to pr_{number}_files)

    Returns:
        Dictionary with information about saved files
    """
    try:
        # Get the pull request
        pr = repo.get_pull(pr_number)

        # Create output directory if not specified
        if output_dir is None:
            output_dir = f"pr_{pr_number}_files"

        # Create the main directory if it doesn't exist
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        # Create a subdirectory with timestamp to avoid conflicts
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        pr_dir = os.path.join(output_dir, f"{pr_number}_{timestamp}")
        os.makedirs(pr_dir)

        # Retrieve all files modified in the PR
        files = pr.get_files()

        file_info = {
            "pr_number": pr_number,
            "pr_title": pr.title,
            "author": pr.user.login,
            "saved_files": [],
            "skipped_files": []
        }

        for file in files:
            try:
                # Skip deleted files
                if file.status == "removed":
                    file_info["skipped_files"].append({
                        "filename": file.filename,
                        "reason": "file was deleted in PR"
                    })
                    continue

                # Get the content of the file at the head of the PR
                content = repo.get_contents(file.filename, ref=pr.head.sha)

                # Create necessary subdirectories
                file_path = os.path.join(pr_dir, file.filename)
                os.makedirs(os.path.dirname(file_path), exist_ok=True)

                # Decode and save the file
                if isinstance(content, list):
                    # This is a directory, skip it
                    file_info["skipped_files"].append({
                        "filename": file.filename,
                        "reason": "is a directory"
                    })
                    continue

                # Save file content
                with open(file_path, 'wb') as f:
                    f.write(content.decoded_content)

                file_info["saved_files"].append({
                    "filename": file.filename,
                    "path": file_path,
                    "additions": file.additions,
                    "deletions": file.deletions,
                    "changes": file.changes,
                    "status": file.status
                })

                print(f"Saved: {file.filename}")

            except Exception as e:
                print(f"Error saving file {file.filename}: {e}")
                file_info["skipped_files"].append({
                    "filename": file.filename,
                    "reason": str(e)
                })

        # Save metadata about this PR's files
        metadata_path = os.path.join(pr_dir, "_metadata.json")
        with open(metadata_path, 'w') as f:
            json.dump(file_info, f, indent=2)

        print(f"Saved {len(file_info['saved_files'])} files for PR #{pr_number}")
        print(f"Skipped {len(file_info['skipped_files'])} files")
        print(f"Files saved to: {pr_dir}")

        return file_info

    except Exception as e:
        print(f"Error retrieving PR #{pr_number}: {e}")
        return None


def retrieve_files_for_all_prs(repo, pr_issue_mapping=None, output_base_dir="pr_files"):
    """
    Retrieve files from all PRs in the mapping.

    Args:
        repo: GitHub repository object
        pr_issue_mapping: Dictionary mapping PR numbers to PR data
        output_base_dir: Base directory to save all PR files

    Returns:
        Dictionary with information about all saved files
    """
    # Load mapping from file if not provided
    if pr_issue_mapping is None:
        with open('pr_issue_mapping.json', 'r') as f:
            pr_issue_mapping = json.load(f)

    # Create output directory
    if not os.path.exists(output_base_dir):
        os.makedirs(output_base_dir)

    # Track results
    retrieval_results = {}

    # Process each PR
    for pr_number in pr_issue_mapping:
        pr_number = int(pr_number)  # Convert string keys back to integers

        print(f"\nRetrieving files for PR #{pr_number}...")
        file_info = retrieve_pr_file_contents(repo, pr_number, output_base_dir)

        if file_info:
            retrieval_results[pr_number] = file_info

    # Save summary of all retrievals
    with open(os.path.join(output_base_dir, "retrieval_summary.json"), 'w') as f:
        json.dump({
            "total_prs_processed": len(retrieval_results),
            "total_files_saved": sum(
                len(info["saved_files"]) for info in retrieval_results.values()),
            "total_files_skipped": sum(
                len(info["skipped_files"]) for info in retrieval_results.values()),
            "pr_summary": {
                pr_num: {
                    "files_saved": len(info["saved_files"]),
                    "files_skipped": len(info["skipped_files"])
                }
                for pr_num, info in retrieval_results.items()
            }
        }, f, indent=2)

    print(f"\nProcessed {len(retrieval_results)} PRs")
    print(f"Results saved to {output_base_dir}")

    return retrieval_results


def analyze_issue_solvers_with_file_content(repo, pr_issue_mapping=None, retrieve_files=False):
    """
    Enhanced version of analyze_issue_solvers that also retrieves file contents.
    """
    # First, perform regular analysis
    issue_solver_data = analyze_issue_solvers(repo, pr_issue_mapping)

    # If requested, retrieve all file contents
    if retrieve_files:
        print("\nRetrieving file contents for all PRs...")
        retrieve_files_for_all_prs(repo, pr_issue_mapping)

    return issue_solver_data

# Example usage
if __name__ == "__main__":
    # Initialize GitHub client
    GITHUB_TOKEN = "" #token is removed because github is not allowing it to be uploaded
    REPO_NAME = "tensorflow/tensorflow"
    g = Github(GITHUB_TOKEN)

    # Get repository
    repo = g.get_repo(REPO_NAME)

    # Step 1: Create PR to issue mapping (start with PRs)
    pr_issue_mapping = map_prs_to_issues(repo, max_prs=1000)

    # Step 2: Analyze PR details to determine issue solvers
    # issue_solver_data = analyze_issue_solvers(repo, pr_issue_mapping)

    issue_solver_data = analyze_issue_solvers_with_file_content(repo, pr_issue_mapping, retrieve_files=True)


    # Step 3: Generate statistics about solvers
    solver_stats = generate_solver_stats(issue_solver_data)

    # Print top solvers
    print("\nTop Issue Solvers:")
    for i, solver_data in enumerate(solver_stats["solvers_by_issues"][:10]):
        print(f"{i+1}. {solver_data['solver']}: {solver_data['issues_solved']} issues, {solver_data['total_changes']} changes")
# Out:
# PR #88868 references issues: [23427]
# PR #88844 references issues: [23485]
# PR #88813 references issues: [23414]
# PR #88818 references issues: [23349]
# PR #88849 references issues: [23340]
# PR #88836 references issues: [23477]
# PR #88792 references issues: [23423]
# PR #88768 references issues: [21638]
# PR #88592 references issues: [88221]
# PR #88765 references issues: [23395]
# PR #88718 references issues: [23307]
# PR #88593 references issues: [23060]
# PR #88693 references issues: [22968]
# PR #88749 references issues: [22808]
# PR #88748 references issues: [22799]
# PR #88745 references issues: [23433]
# PR #88561 references issues: [23232]
# PR #88690 references issues: [22383]
# PR #88628 references issues: [20399]
# PR #88178 references issues: [23018]
# PR #88596 references issues: [23355]
# PR #88568 references issues: [23351]
# PR #88556 references issues: [22897]
# PR #88180 references issues: [23020]
# PR #88523 references issues: [23271]
# PR #88269 references issues: [23181]
# PR #88522 references issues: [23051]
# PR #88515 references issues: [23237]
# PR #88512 references issues: [22391]
# PR #88482 references issues: [23302]
# PR #88513 references issues: [23301]
# PR #88497 references issues: [23314]
# PR #88232 references issues: [23165]
# PR #88250 references issues: [23019]
# PR #88004 references issues: [22901]
# PR #88097 references issues: [22437]
# PR #88126 references issues: [23092]
# PR #88056 references issues: [23061]
# PR #88030 references issues: [23078]
# PR #88048 references issues: [22898]
# PR #87990 references issues: [22930]
# PR #87992 references issues: [22953]
# PR #87991 references issues: [22956]
# PR #87974 references issues: [22822]
# PR #87936 references issues: [22970]
# PR #87458 references issues: [22614]
# PR #87691 references issues: [22758]
# PR #87751 references issues: [87613]
# PR #87651 references issues: [22826]
# PR #87428 references issues: [22782]
# PR #87595 references issues: [22829]
# PR #86945 references issues: [21965]
# PR #87528 references issues: [87409]
# PR #87490 references issues: [22815]
# PR #87512 references issues: [22830]
# PR #87510 references issues: [87305]
# PR #87467 references issues: [22723]
# PR #86308 references issues: [21886]
# PR #87422 references issues: [22385]
# PR #86303 references issues: [21746]
# PR #87308 references issues: [22575]
# PR #87342 references issues: [22757]
# PR #87407 references issues: [22706]
# PR #87307 references issues: [22680]
# PR #87317 references issues: [22640]
# PR #87251 references issues: [22645]
# PR #87266 references issues: [86630]
# PR #87261 references issues: [22588]
# PR #87225 references issues: [22572]
# PR #87060 references issues: [22554]
# PR #87240 references issues: [22593]
# PR #87052 references issues: [20332]
# PR #87136 references issues: [22532]
# PR #87055 references issues: [22509]
# PR #87056 references issues: [22537]
# PR #87057 references issues: [22529]
# PR #87121 references issues: [22512]
# PR #86555 references issues: [19834]
# Mapped 78 PRs to their referenced issues
# Issue #23427 (Build failing with ` ERROR: Config value cuda is not defined in any .rc file`) was solved by: shawnwang18
# Error retrieving details for issue #23485: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/issues/issues#get-an-issue", "status": "404"}
# Issue #23414 (Improve shape function of tf.sparse_reduce_sum) was solved by: sergachev
# Issue #23349 (my CNN models print NAN. what is reason??? i don't know what is it.) was solved by: jreiffers
# Issue #23340 (TFLite object detection toco error(the size of detect.tflite is 0kb)) was solved by: mmakevic-amd
# Issue #23477 (Tensorflow's Estimator stops training) was solved by: JackWolfard
# Issue #23423 (Should use '_train_distribution' because Estimator doesn't have attribute '_distribution') was solved by: apivovarov
# Issue #21638 ([XLA] ResourceExhaustedError when trying to define a Sequential model in Keras under jit_scope context manager) was solved by: zhenying-liu
# Issue #88221 (Qualcomm AI Engine Direct - Op Builders for 1P Models) was solved by: weilhuan-quic
# Issue #23395 (deploying the Tensorflow model in Python) was solved by: i-chaochen
# Issue #23307 (Missing Documentation: Multiple links return 404 in Python API Guide) was solved by: afzpatel
# Issue #23060 (Attributes values not inferred by TFE C API (eager mode)) was solved by: shawnwang18
# Issue #22968 (remove noisy warning in StepCounterHook) was solved by: sfvaroglu
# Issue #22808 ([Documentation] Format example list.) was solved by: shraiysh
# Issue #22799 (1.12-rc0 cherry-pick request: Mark tensorflow/contrib/tpu:datasets_test flaky) was solved by: shraiysh
# Issue #23433 ([nGraph] Updated to nGraph version v0.9.1 and ngraph-tf version v0.7.0) was solved by: ImanHosseini
# Issue #23232 (Broken distributed training with tf.estimator.Estimator) was solved by: jreiffers
# Issue #22383 (Inconsistency in tf.nn.top_k when using sorted=False and tf.float32 tensor and GPU placement) was solved by: hsharsha
# Issue #20399 (Feature request: A Layer object wrapping multiple Layer objects) was solved by: philipphack
# Issue #23018 (.) was solved by: dependabot[bot]
# Issue #23355 (Failed to load) was solved by: mmakevic-amd
# Issue #23351 (fake_quant_min_max_args/vars works unexpected) was solved by: hsharsha
# Issue #22897 (Conversion from pb to tflite fails) was solved by: sergachev
# Issue #23020 (Error in C++ Tensorflow to load model trained by python) was solved by: dependabot[bot]
# Issue #23271 (Improve shape function of tf.sparse_reduce_sum) was solved by: zhenying-liu
# Issue #23181 (how to get the Projective transform matrix ,which will be used to tf.contrib.image.transform??) was solved by: jreiffers
# Issue #23051 ([Experiment] Reformat issue template. <DO NOT MERGE>) was solved by: sergachev
# Issue #23237 (1.12.0-rc2 cherry-pick request: Fix string comparison in `configured`) was solved by: mmakevic-amd
# Issue #22391 (Fixed broken links) was solved by: johnnkp
# Issue #23302 (Autotune seems to be "forgetting" after a short delay within the same session.) was solved by: yliu120
# Issue #23301 (Fix T-distribution sampling parameter) was solved by: yliu120
# Issue #23314 (Changing learning rate of the optimizer in eager mode) was solved by: shraiysh
# Issue #23165 (TensorRT engine binding error) was solved by: shawnwang18
# Issue #23019 (`tf.layers.Conv2D`'s padding doesn't allow variable reuse in some cases) was solved by: dependabot[bot]
# Issue #22901 (We have removed this restriction. Please check out the code at head, or in the upcoming 1.4 RC. Please reopen if there are issues with it.) was solved by: shraiysh
# Issue #22437 (tensorflow-1.11.0-rc1 fails to build) was solved by: chaserileyroberts
# Issue #23092 (add interpreter debug func) was solved by: sergachev
# Issue #23061 (Xla and Ignite support always true from configure.py) was solved by: shawnwang18
# Issue #23078 (Building the pip package on Windows) was solved by: sergachev
# Issue #22898 (Error building on Windows // no such package '@flatbuffers) was solved by: sergachev
# Issue #22930 (absl not installed as it is included in stringpiece.h) was solved by: apivovarov
# Issue #22953 (Merge branch r1.12 into master.) was solved by: apivovarov
# Issue #22956 (r1.12-rc1 cherry-pick request: Explicitly set jdk8 in ci_parameterized_build.sh) was solved by: yliu120
# Issue #22822 ([INTEL MKL] Fix bug in MklSlice op when allocating output tensor.) was solved by: apivovarov
# Issue #22970 (protobuf not seem to be recognized but it is installed) was solved by: shraiysh
# Issue #22614 (what is operator name for python corresponding to kReducePrecision) was solved by: shraiysh
# Issue #22758 (Tensorflow CPU 1.5 VS 1.6 on Windows 7 - 64 bits - Bug on 1.6 version) was solved by: dimvar
# Issue #87613 (Explicit print options while dumping HLO) was solved by: tensorflower-gardener, shraiysh
# Issue #22826 (Win10 C++ TF1.9, error LNK2001, build by bazel  !) was solved by: Cjkkkk
# Issue #22782 (Rel notes 1 12) was solved by: sergachev
# Issue #22829 (can tensorflow tensorRT (with multiple outputs) be used for object dectection? can ) was solved by: apivovarov
# Issue #21965 (cannot find  "flatbuffers/flatbuffers.h"  head  file) was solved by: hugomano
# Issue #87409 (Qualcomm AI Engine Direct - Fix copyright format) was solved by: jiunkaiy
# Issue #22815 (Object detection api training issue) was solved by: cerisier
# Issue #22830 (can tensorflow tensorRT be used for  optimization of object detection model) was solved by: sergachev
# Issue #87305 (Qualcomm AI Engine Direct - Another implementation of DUS without accuracy issue.) was solved by: tensorflower-gardener, chunhsue
# Issue #22723 (bug: tf.train.Saver.save() fails if 2 tf.contrib.cudnn_rnn.cudnnLSTM instances passed to saver are built with build() method) was solved by: apivovarov
# Issue #21886 (Tensorflow 1.10.0 MKL build (win-64) with bazel throws linker error) was solved by: pemeliya
# Issue #22385 (session = tf.Session()) was solved by: shawnwang18
# Issue #21746 (Adding op doc fixes) was solved by: terryysun
# Issue #22575 (Preferred way of installing TensorRT with Tensorflow 1.11 on Ubuntu?) was solved by: sergey-kozub
# Issue #22757 (keras.model.predict also needs two inputs (one for sample, and one for label) when used with tf.data together) was solved by: Tixxx
# Issue #22706 (CUDA 10) was solved by: kasper0406
# Issue #22680 (1.12-rc0 cherry-pick request: Pin wheel=0.31.1 to work around issue https://github.com/pypa/auditwheel/issues/102) was solved by: shraiysh
# Issue #22640 (Fix warning for format specifier) was solved by: sergachev
# Issue #22645 (Problem with CUDA 10 and Tensorflow 1.11) was solved by: dimvar
# Issue #86630 (Qualcomm AI Engine Direct - Support DUS and Pack Op in LiteRT) was solved by: tensorflower-gardener, chunhsue
# Issue #22588 (Update the relative file paths in the comments of tf.data kernel files) was solved by: Tixxx
# Issue #22572 ([nGraph] Fixed the broken unit test build) was solved by: mmakevic-amd
# Issue #22554 (Adding custom op instructions lacking the GPU building instructions) was solved by: sergachev
# Issue #22593 ([XLA/tfcompile] fix type of enum for build with MSVC) was solved by: sergey-kozub
# Issue #20332 (An attempt at Tensorflow and Bazel CPU/GPU build (v1.8.0)) was solved by: shraiysh
# Issue #22532 (Tensorflow quantization on Windows) was solved by: hsharsha
# Issue #22509 (Make sure broken tests are filtered out in XLA tests suites.) was solved by: draganmladjenovic
# Issue #22537 (122) was solved by: sergachev
# Issue #22529 (Feature request: Make contrib.receptive_field extensible) was solved by: hsharsha
# Issue #22512 (Installation issue with Tensorflow-cpu, no module named '_pwyrap_tensorflow_internal') was solved by: sergey-kozub
# Issue #19834 (Attention Wrapper state error.) was solved by: shraiysh
#
# Retrieving file contents for all PRs...
#
# Retrieving files for PR #88868...
# Saved: third_party/xla/xla/debug_options_flags.cc
# Saved 1 files for PR #88868
# Skipped 0 files
# Files saved to: pr_files/88868_20250307_202615
#
# Retrieving files for PR #88844...
# Saved: third_party/xla/build_tools/configure/configure.py
# Saved 1 files for PR #88844
# Skipped 0 files
# Files saved to: pr_files/88844_20250307_202617
#
# Retrieving files for PR #88813...
# Saved: third_party/xla/xla/backends/gpu/codegen/BUILD
# Saved: third_party/xla/xla/backends/gpu/codegen/cudnn_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/cudnn_fusion_compiler.cc
# Saved 3 files for PR #88813
# Skipped 0 files
# Files saved to: pr_files/88813_20250307_202619
#
# Retrieving files for PR #88818...
# Saved: third_party/xla/xla/service/gpu/ir_emission_utils.cc
# Saved: third_party/xla/xla/service/gpu/ir_emission_utils.h
# Saved: third_party/xla/xla/service/gpu/ir_emission_utils_test.cc
# Saved 3 files for PR #88818
# Skipped 0 files
# Files saved to: pr_files/88818_20250307_202621
#
# Retrieving files for PR #88849...
# Saved: third_party/xla/tensorflow.bazelrc
# Saved 1 files for PR #88849
# Skipped 0 files
# Files saved to: pr_files/88849_20250307_202624
#
# Retrieving files for PR #88836...
# Saved: third_party/gpus/cuda/hermetic/cuda_redist_init_repositories.bzl
# Saved: third_party/xla/third_party/gpus/cuda/hermetic/cuda_redist_init_repositories.bzl
# Saved 2 files for PR #88836
# Skipped 0 files
# Files saved to: pr_files/88836_20250307_202626
#
# Retrieving files for PR #88792...
# Saved: third_party/xla/xla/hlo/transforms/simplifiers/hlo_constant_folding.cc
# Saved: third_party/xla/xla/hlo/transforms/simplifiers/hlo_constant_folding_test.cc
# Saved 2 files for PR #88792
# Skipped 0 files
# Files saved to: pr_files/88792_20250307_202629
#
# Retrieving files for PR #88768...
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/service/hlo_verifier.cc
# Saved: third_party/xla/xla/service/hlo_verifier.h
# Saved: third_party/xla/xla/service/hlo_verifier_test.cc
# Saved 4 files for PR #88768
# Skipped 0 files
# Files saved to: pr_files/88768_20250307_202631
#
# Retrieving files for PR #88592...
# Saved: tensorflow/lite/experimental/litert/c/litert_options.cc
# Saved: tensorflow/lite/experimental/litert/c/litert_options.h
# Saved: tensorflow/lite/experimental/litert/c/litert_options_test.cc
# Saved: tensorflow/lite/experimental/litert/tools/dump.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/qnn_compiler_plugin_test.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/qnn_compose_graph.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/conv2d_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/conv2d_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/depthwise_conv2d_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/depthwise_conv2d_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/hard_swish_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/hard_swish_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/leaky_relu_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/leaky_relu_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pool2d_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pool2d_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/resize_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/resize_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/spatial_transform_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/spatial_transform_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/tensor_wrapper.h
# Saved 27 files for PR #88592
# Skipped 0 files
# Files saved to: pr_files/88592_20250307_202634
#
# Retrieving files for PR #88765...
# Saved: third_party/xla/xla/stream_executor/device_description.h
# Saved 1 files for PR #88765
# Skipped 0 files
# Files saved to: pr_files/88765_20250307_202650
#
# Retrieving files for PR #88718...
# Saved: third_party/gpus/rocm/BUILD.tpl
# Saved: third_party/gpus/rocm_configure.bzl
# Saved: third_party/xla/tensorflow.bazelrc
# Saved: third_party/xla/third_party/gpus/rocm/BUILD.tpl
# Saved: third_party/xla/third_party/gpus/rocm_configure.bzl
# Saved 5 files for PR #88718
# Skipped 0 files
# Files saved to: pr_files/88718_20250307_202653
#
# Retrieving files for PR #88593...
# Saved: third_party/xla/xla/tests/client_library_test_base.cc
# Saved: third_party/xla/xla/tests/client_library_test_base.h
# Saved: third_party/xla/xla/tests/client_library_test_runner_mixin.h
# Saved 3 files for PR #88593
# Skipped 0 files
# Files saved to: pr_files/88593_20250307_202657
#
# Retrieving files for PR #88693...
# Saved: third_party/xla/xla/debug_options_flags.cc
# Saved: third_party/xla/xla/service/gpu/BUILD
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/tools/hlo_opt/BUILD
# Saved: third_party/xla/xla/tools/hlo_opt/gpu_opt.cc
# Saved: third_party/xla/xla/tools/hlo_opt/tests/gpu_hlo_collective_cse.hlo
# Saved: third_party/xla/xla/xla.proto
# Saved 7 files for PR #88693
# Skipped 0 files
# Files saved to: pr_files/88693_20250307_202700
#
# Retrieving files for PR #88749...
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/service/gpu/gpu_compiler_test.cc
# Saved 2 files for PR #88749
# Skipped 0 files
# Files saved to: pr_files/88749_20250307_202705
#
# Retrieving files for PR #88748...
# Saved: third_party/xla/xla/backends/gpu/codegen/custom.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/dynamic_slice_fusion_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/dynamic_slice_fusion_rewriter.cc
# Saved: third_party/xla/xla/service/gpu/transforms/dynamic_slice_fusion_rewriter_test.cc
# Saved 4 files for PR #88748
# Skipped 0 files
# Files saved to: pr_files/88748_20250307_202707
#
# Retrieving files for PR #88745...
# Saved: third_party/xla/xla/pjrt/c/README.md
# Saved 1 files for PR #88745
# Skipped 0 files
# Files saved to: pr_files/88745_20250307_202711
#
# Retrieving files for PR #88561...
# Saved: third_party/xla/xla/backends/gpu/runtime/BUILD
# Saved: third_party/xla/xla/backends/gpu/runtime/for_all_thunks_test.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/while_thunk.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/while_thunk.h
# Saved: third_party/xla/xla/backends/gpu/runtime/while_thunk_test.cc
# Saved: third_party/xla/xla/service/gpu/ir_emitter_unnested.cc
# Saved 6 files for PR #88561
# Skipped 0 files
# Files saved to: pr_files/88561_20250307_202713
#
# Retrieving files for PR #88690...
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_executor.cc
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_executor.h
# Saved 2 files for PR #88690
# Skipped 0 files
# Files saved to: pr_files/88690_20250307_202717
#
# Retrieving files for PR #88628...
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/tests/collective_ops_e2e_test.cc
# Saved 2 files for PR #88628
# Skipped 0 files
# Files saved to: pr_files/88628_20250307_202720
#
# Retrieving files for PR #88178...
# Saved: third_party/xla/.github/workflows/scorecards-analysis.yml
# Saved 1 files for PR #88178
# Skipped 0 files
# Files saved to: pr_files/88178_20250307_202722
#
# Retrieving files for PR #88596...
# Saved: third_party/xla/build_tools/rocm/run_xla.sh
# Saved: third_party/xla/build_tools/rocm/run_xla_multi_gpu.sh
# Saved: third_party/xla/tensorflow.bazelrc
# Saved 3 files for PR #88596
# Skipped 0 files
# Files saved to: pr_files/88596_20250307_202724
#
# Retrieving files for PR #88568...
# Saved: third_party/xla/tensorflow.bazelrc
# Saved 1 files for PR #88568
# Skipped 0 files
# Files saved to: pr_files/88568_20250307_202727
#
# Retrieving files for PR #88556...
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/functional_hlo_runner.cc
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/functional_hlo_runner_test.cc
# Saved 2 files for PR #88556
# Skipped 0 files
# Files saved to: pr_files/88556_20250307_202729
#
# Retrieving files for PR #88180...
# Saved: third_party/xla/.github/workflows/scorecards-analysis.yml
# Saved 1 files for PR #88180
# Skipped 0 files
# Files saved to: pr_files/88180_20250307_202732
#
# Retrieving files for PR #88523...
# Saved: third_party/xla/xla/service/gpu/BUILD
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/service/gpu/gpu_hlo_schedule.cc
# Saved: third_party/xla/xla/service/gpu/gpu_hlo_schedule.h
# Saved: third_party/xla/xla/service/gpu/gpu_hlo_schedule_test.cc
# Saved: third_party/xla/xla/service/gpu/gpu_latency_hiding_scheduler.cc
# Saved: third_party/xla/xla/service/gpu/gpu_latency_hiding_scheduler.h
# Saved: third_party/xla/xla/service/gpu/nvptx_compiler_test.cc
# Saved 8 files for PR #88523
# Skipped 0 files
# Files saved to: pr_files/88523_20250307_202734
#
# Retrieving files for PR #88269...
# Saved: third_party/xla/xla/hlo/transforms/while_loop_trip_count_annotator.cc
# Saved: third_party/xla/xla/hlo/transforms/while_loop_trip_count_annotator_test.cc
# Saved: third_party/xla/xla/xla_data.proto
# Saved 3 files for PR #88269
# Skipped 0 files
# Files saved to: pr_files/88269_20250307_202739
#
# Retrieving files for PR #88522...
# Saved: third_party/xla/xla/service/gpu/BUILD
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.h
# Saved: third_party/xla/xla/service/gpu/pre_scheduling_copy_insertion_pipeline.cc
# Saved: third_party/xla/xla/service/gpu/pre_scheduling_copy_insertion_pipeline.h
# Saved 5 files for PR #88522
# Skipped 0 files
# Files saved to: pr_files/88522_20250307_202742
#
# Retrieving files for PR #88515...
# Saved: third_party/xla/xla/service/gpu/llvm_gpu_backend/amdgpu_backend.cc
# Saved: third_party/xla/xla/stream_executor/device_description.h
# Saved 2 files for PR #88515
# Skipped 0 files
# Files saved to: pr_files/88515_20250307_202746
#
# Retrieving files for PR #88512...
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_blas.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_dnn.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_fft.cc
# Saved 3 files for PR #88512
# Skipped 0 files
# Files saved to: pr_files/88512_20250307_202749
#
# Retrieving files for PR #88482...
# Saved: third_party/xla/xla/pjrt/gpu/se_gpu_pjrt_client_test.cc
# Saved 1 files for PR #88482
# Skipped 0 files
# Files saved to: pr_files/88482_20250307_202752
#
# Retrieving files for PR #88513...
# Saved: third_party/xla/xla/service/BUILD
# Saved: third_party/xla/xla/service/custom_call_sharding_helper.cc
# Saved: third_party/xla/xla/service/custom_call_sharding_helper.h
# Saved 3 files for PR #88513
# Skipped 0 files
# Files saved to: pr_files/88513_20250307_202754
#
# Retrieving files for PR #88497...
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved 1 files for PR #88497
# Skipped 0 files
# Files saved to: pr_files/88497_20250307_202757
#
# Retrieving files for PR #88232...
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd_emitter.cc
# Saved: third_party/xla/xla/debug_options_flags.cc
# Saved: third_party/xla/xla/tests/client_library_test_base.cc
# Saved: third_party/xla/xla/tests/client_library_test_base.h
# Saved: third_party/xla/xla/tests/conditional_test.cc
# Saved: third_party/xla/xla/xla.proto
# Saved 6 files for PR #88232
# Skipped 0 files
# Files saved to: pr_files/88232_20250307_202759
#
# Retrieving files for PR #88250...
# Saved: third_party/xla/.github/workflows/gpu_benchmarks.yml
# Saved: third_party/xla/.github/workflows/scorecards-analysis.yml
# Saved 2 files for PR #88250
# Skipped 0 files
# Files saved to: pr_files/88250_20250307_202803
#
# Retrieving files for PR #88004...
# Saved: tensorflow/compiler/tf2xla/kernels/resampler_ops.cc
# Saved: tensorflow/core/tpu/kernels/xla/get_item_op.cc
# Saved: third_party/xla/docs/operation_semantics.md
# Saved: third_party/xla/xla/hlo/builder/xla_builder.cc
# Saved: third_party/xla/xla/hlo/builder/xla_builder.h
# Saved: third_party/xla/xla/hlo/builder/xla_builder_test.cc
# Saved: third_party/xla/xla/python/ops.cc
# Saved: third_party/xla/xla/python/xla_client_test.py
# Saved: third_party/xla/xla/python/xla_extension/ops.pyi
# Saved: third_party/xla/xla/service/shape_inference.cc
# Saved: third_party/xla/xla/service/shape_inference.h
# Saved: third_party/xla/xla/service/shape_inference_test.cc
# Saved: third_party/xla/xla/tests/bitcast_convert_test.cc
# Saved: third_party/xla/xla/tests/convert_test.cc
# Saved: third_party/xla/xla/tests/dot_operation_test.cc
# Saved: third_party/xla/xla/tests/reshape_test.cc
# Saved: third_party/xla/xla/tests/select_and_scatter_test.cc
# Saved: third_party/xla/xla/tests/while_test.cc
# Saved 18 files for PR #88004
# Skipped 0 files
# Files saved to: pr_files/88004_20250307_202806
#
# Retrieving files for PR #88097...
# Saved: third_party/xla/xla/hlo/ir/hlo_instruction.h
# Saved: third_party/xla/xla/hlo/ir/hlo_instruction_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/BUILD
# Saved: third_party/xla/xla/service/gpu/transforms/explicit_stream_annotation_async_wrapper.cc
# Saved: third_party/xla/xla/service/gpu/transforms/explicit_stream_annotation_async_wrapper_test.cc
# Saved 5 files for PR #88097
# Skipped 0 files
# Files saved to: pr_files/88097_20250307_202818
#
# Retrieving files for PR #88126...
# Saved: third_party/xla/xla/backends/profiler/cpu/BUILD
# Saved: third_party/xla/xla/backends/profiler/cpu/host_tracer_test.cc
# Saved: third_party/xla/xla/backends/profiler/gpu/BUILD
# Saved: third_party/xla/xla/backends/profiler/gpu/cupti_tracer.h
# Saved: third_party/xla/xla/backends/profiler/gpu/rocm_collector.cc
# Saved: third_party/xla/xla/backends/profiler/gpu/rocm_tracer.h
# Saved: third_party/xla/xla/hlo/translate/hlo_to_mhlo/BUILD
# Saved: third_party/xla/xla/hlo/translate/hlo_to_mhlo/hlo_function_importer.cc
# Saved: third_party/xla/xla/hlo/translate/hlo_to_mhlo/hlo_function_importer.h
# Saved: third_party/xla/xla/python/BUILD
# Saved: third_party/xla/xla/python/ifrt_proxy/client/BUILD
# Saved: third_party/xla/xla/python/ifrt_proxy/client/array.h
# Saved: third_party/xla/xla/python/ifrt_proxy/client/client.h
# Saved: third_party/xla/xla/python/xplane_to_profile_instructions.cc
# Saved: third_party/xla/xla/tsl/framework/BUILD
# Saved: third_party/xla/xla/tsl/framework/allocator.h
# Saved: third_party/xla/xla/tsl/framework/allocator_retry.cc
# Saved: third_party/xla/xla/tsl/framework/cpu_allocator_impl.cc
# Saved: third_party/xla/xla/tsl/framework/tracking_allocator.cc
# Saved: third_party/xla/xla/tsl/framework/tracking_allocator.h
# Saved: third_party/xla/xla/tsl/platform/default/BUILD
# Saved: third_party/xla/xla/tsl/platform/status.h
# Saved: third_party/xla/xla/tsl/platform/threadpool.cc
# Saved: third_party/xla/xla/tsl/platform/threadpool.h
# Saved: third_party/xla/xla/tsl/platform/windows/BUILD
# Saved: third_party/xla/xla/tsl/profiler/convert/BUILD
# Saved: third_party/xla/xla/tsl/profiler/convert/xplane_to_trace_events.cc
# Saved: third_party/xla/xla/tsl/profiler/utils/BUILD
# Saved: third_party/xla/xla/tsl/profiler/utils/group_events.h
# Saved: third_party/xla/xla/tsl/profiler/utils/preprocess_xplane.h
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_builder.cc
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_builder.h
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_schema.cc
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_schema.h
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_utils_test.cc
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_visitor.cc
# Saved: third_party/xla/xla/tsl/profiler/utils/xplane_visitor.h
# Saved 37 files for PR #88126
# Skipped 0 files
# Files saved to: pr_files/88126_20250307_202822
#
# Retrieving files for PR #88056...
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_command_buffer.cc
# Saved 3 files for PR #88056
# Skipped 0 files
# Files saved to: pr_files/88056_20250307_202844
#
# Retrieving files for PR #88030...
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd.cc
# Saved: third_party/xla/xla/stream_executor/BUILD
# Saved: third_party/xla/xla/stream_executor/command_buffer.h
# Saved: third_party/xla/xla/stream_executor/cuda/BUILD
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_command_buffer.h
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_dnn.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_dnn.h
# Saved: third_party/xla/xla/stream_executor/dnn.h
# Saved: third_party/xla/xla/stream_executor/gpu/BUILD
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer.h
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer_test.cc
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_command_buffer.h
# Saved 14 files for PR #88030
# Skipped 0 files
# Files saved to: pr_files/88030_20250307_202847
#
# Retrieving files for PR #88048...
# Saved: third_party/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc
# Saved 1 files for PR #88048
# Skipped 0 files
# Files saved to: pr_files/88048_20250307_202856
#
# Retrieving files for PR #87990...
# Saved: third_party/xla/xla/service/heap_simulator/heap_simulator.cc
# Saved 1 files for PR #87990
# Skipped 0 files
# Files saved to: pr_files/87990_20250307_202858
#
# Retrieving files for PR #87992...
# Saved: third_party/xla/xla/status_macros.cc
# Saved 1 files for PR #87992
# Skipped 0 files
# Files saved to: pr_files/87992_20250307_202900
#
# Retrieving files for PR #87991...
# Saved: third_party/xla/xla/backends/gpu/runtime/while_thunk.cc
# Saved 1 files for PR #87991
# Skipped 0 files
# Files saved to: pr_files/87991_20250307_202902
#
# Retrieving files for PR #87974...
# Saved: third_party/xla/xla/service/collective_permute_cycle_test.cc
# Saved 1 files for PR #87974
# Skipped 0 files
# Files saved to: pr_files/87974_20250307_202904
#
# Retrieving files for PR #87936...
# Saved: third_party/xla/xla/hlo/ir/hlo_computation.cc
# Saved: third_party/xla/xla/service/hlo_computation_test.cc
# Saved 2 files for PR #87936
# Skipped 0 files
# Files saved to: pr_files/87936_20250307_202905
#
# Retrieving files for PR #87458...
# Saved: third_party/xla/xla/hlo/ir/BUILD
# Saved: third_party/xla/xla/hlo/ir/hlo_module.cc
# Saved: third_party/xla/xla/hlo/ir/hlo_module.h
# Saved: third_party/xla/xla/hlo/ir/hlo_module_test.cc
# Saved: third_party/xla/xla/hlo/tools/tests/convert_to_text.hlo
# Saved: third_party/xla/xla/service/dump.cc
# Saved: third_party/xla/xla/service/hlo_instruction_test.cc
# Saved 7 files for PR #87458
# Skipped 0 files
# Files saved to: pr_files/87458_20250307_202908
#
# Retrieving files for PR #87691...
# Saved: third_party/xla/xla/service/elemental_ir_emitter_test.cc
# Saved: third_party/xla/xla/service/gpu/autotuning/gemm_fusion_autotuner_test.cc
# Saved: third_party/xla/xla/service/gpu/gpu_compiler_test.cc
# Saved 3 files for PR #87691
# Skipped 0 files
# Files saved to: pr_files/87691_20250307_202913
#
# Retrieving files for PR #87751...
# Saved: tensorflow/compiler/aot/tests/tfcompile_test.cc
# Saved: tensorflow/compiler/jit/get_compiler_ir.cc
# Saved: tensorflow/compiler/mlir/tensorflow/utils/tf_xla_mlir_translate.cc
# Saved 3 files for PR #87751
# Skipped 0 files
# Files saved to: pr_files/87751_20250307_202916
#
# Retrieving files for PR #87651...
# Saved: third_party/xla/xla/service/gpu/tests/gpu_fused_mha_test.cc
# Saved 1 files for PR #87651
# Skipped 0 files
# Files saved to: pr_files/87651_20250307_202919
#
# Retrieving files for PR #87428...
# Saved: tensorflow/compiler/tf2xla/BUILD
# Saved: tensorflow/compiler/tf2xla/xla_compiler_test.cc
# Saved: third_party/xla/xla/service/BUILD
# Saved: third_party/xla/xla/service/hlo_module_util.cc
# Saved: third_party/xla/xla/service/hlo_module_util.h
# Saved: third_party/xla/xla/service/hlo_proto_util.cc
# Saved: third_party/xla/xla/service/hlo_proto_util.h
# Saved: third_party/xla/xla/service/hlo_runner_interface.cc
# Saved: third_party/xla/xla/service/hlo_runner_interface.h
# Saved: third_party/xla/xla/tests/BUILD
# Saved: third_party/xla/xla/tests/hlo_test_base.cc
# Saved: third_party/xla/xla/tests/token_hlo_test.cc
# Saved: third_party/xla/xla/tools/BUILD
# Saved: third_party/xla/xla/tools/hlo_bisect/BUILD
# Saved: third_party/xla/xla/tools/hlo_bisect/hlo_bisect_utils.cc
# Saved: third_party/xla/xla/tools/interactive_graphviz.cc
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/BUILD
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/functional_hlo_runner.cc
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/hlo_runner_main.cc
# Saved 19 files for PR #87428
# Skipped 0 files
# Files saved to: pr_files/87428_20250307_202921
#
# Retrieving files for PR #87595...
# Saved: third_party/xla/build_tools/configure/configure.py
# Saved: third_party/xla/build_tools/configure/testdata/gcc.bazelrc
# Saved: third_party/xla/build_tools/configure/testdata/nvcc_gcc.bazelrc
# Saved 3 files for PR #87595
# Skipped 0 files
# Files saved to: pr_files/87595_20250307_202933
#
# Retrieving files for PR #86945...
# Saved: third_party/xla/xla/pjrt/c/BUILD
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_gpu_internal.cc
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_gpu_test.cc
# Saved: third_party/xla/xla/pjrt/gpu/se_gpu_pjrt_client_test.cc
# Saved 4 files for PR #86945
# Skipped 0 files
# Files saved to: pr_files/86945_20250307_202936
#
# Retrieving files for PR #87528...
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/cast_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/cast_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/concatenation_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/concatenation_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/dynamic_update_slice_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/dynamic_update_slice_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/elementwise_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/elementwise_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/embedding_lookup_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/embedding_lookup_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/fully_connected_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/fully_connected_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/gather_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/gather_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/gelu_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/gelu_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/matmul_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/matmul_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/mean_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/mean_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pack_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pack_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/quantize_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/quantize_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/reduce_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/reduce_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/reshape_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/reshape_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/select_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/select_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/slice_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/slice_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/softmax_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/softmax_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/split_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/split_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/tanh_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/tanh_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/transpose_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/transpose_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/tensor_pool.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/tensor_pool.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/op_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/op_wrapper.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/param_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/param_wrapper.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/tensor_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/tensor_wrapper.h
# Saved 55 files for PR #87528
# Skipped 0 files
# Files saved to: pr_files/87528_20250307_202940
#
# Retrieving files for PR #87490...
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_custom_partitioner_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_ffi_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_layouts_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_memory_descriptions_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_profiler_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_stream_extension.h
# Saved: third_party/xla/xla/pjrt/c/pjrt_c_api_triton_extension.h
# Saved 7 files for PR #87490
# Skipped 0 files
# Files saved to: pr_files/87490_20250307_203011
#
# Retrieving files for PR #87512...
# Saved: third_party/xla/tsl_workspace2.bzl
# Saved: third_party/xla/tsl_workspace3.bzl
# Saved 2 files for PR #87512
# Skipped 0 files
# Files saved to: pr_files/87512_20250307_203016
#
# Retrieving files for PR #87510...
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/dynamic_update_slice_op_builder.cc
# Saved 2 files for PR #87510
# Skipped 0 files
# Files saved to: pr_files/87510_20250307_203019
#
# Retrieving files for PR #87467...
# Saved: third_party/xla/xla/hlo/experimental/auto_sharding/auto_sharding.h
# Saved: third_party/xla/xla/hlo/experimental/auto_sharding/auto_sharding_util.cc
# Saved: third_party/xla/xla/hlo/experimental/auto_sharding/auto_sharding_util.h
# Saved 3 files for PR #87467
# Skipped 0 files
# Files saved to: pr_files/87467_20250307_203021
#
# Retrieving files for PR #86308...
# Saved: tensorflow/core/kernels/matmul_util.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd.h
# Saved: third_party/xla/xla/backends/gpu/runtime/gpublas_lt_matmul_thunk.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/gpublas_lt_matmul_thunk.h
# Saved: third_party/xla/xla/service/gpu/autotuning/gemm_algorithm_picker.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_blas_lt.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_blas_lt.h
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_blas_lt.h
# Saved: third_party/xla/xla/stream_executor/rocm/BUILD
# Saved: third_party/xla/xla/stream_executor/rocm/hip_blas_lt.cc
# Saved: third_party/xla/xla/stream_executor/rocm/hip_blas_lt.h
# Saved 12 files for PR #86308
# Skipped 0 files
# Files saved to: pr_files/86308_20250307_203024
#
# Retrieving files for PR #87422...
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd.h
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_cmd_emitter.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/command_buffer_thunk_test.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/conditional_thunk.h
# Saved: third_party/xla/xla/stream_executor/command_buffer.h
# Saved: third_party/xla/xla/stream_executor/cuda/command_buffer_kernels.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/cuda/cuda_command_buffer.h
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/gpu/gpu_command_buffer.h
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_command_buffer.cc
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_command_buffer.h
# Saved: third_party/xla/xla/tests/conditional_test.cc
# Saved 14 files for PR #87422
# Skipped 0 files
# Files saved to: pr_files/87422_20250307_203032
#
# Retrieving files for PR #86303...
# Saved: third_party/xla/xla/hlo/transforms/collectives/BUILD
# Saved: third_party/xla/xla/hlo/transforms/collectives/collective_permute_combiner.cc
# Saved: third_party/xla/xla/hlo/transforms/collectives/collective_permute_combiner.h
# Saved: third_party/xla/xla/hlo/transforms/collectives/collective_permute_combiner_test.cc
# Saved: third_party/xla/xla/service/BUILD
# Saved: third_party/xla/xla/service/collective_permute_key.cc
# Saved: third_party/xla/xla/service/collective_permute_key.h
# Saved 7 files for PR #86303
# Skipped 0 files
# Files saved to: pr_files/86303_20250307_203041
#
# Retrieving files for PR #87308...
# Saved: third_party/xla/xla/backends/gpu/codegen/triton/transforms/sparse_passes.cc
# Saved 1 files for PR #87308
# Skipped 0 files
# Files saved to: pr_files/87308_20250307_203047
#
# Retrieving files for PR #87342...
# Saved: third_party/xla/xla/backends/gpu/runtime/nccl_collective_permute_thunk.cc
# Saved 1 files for PR #87342
# Skipped 0 files
# Files saved to: pr_files/87342_20250307_203048
#
# Retrieving files for PR #87407...
# Saved: third_party/xla/xla/service/cpu/cpu_compiler.cc
# Saved 1 files for PR #87407
# Skipped 0 files
# Files saved to: pr_files/87407_20250307_203050
#
# Retrieving files for PR #87307...
# Saved: third_party/xla/xla/debug_options_flags.cc
# Saved 1 files for PR #87307
# Skipped 0 files
# Files saved to: pr_files/87307_20250307_203052
#
# Retrieving files for PR #87317...
# Saved: third_party/xla/xla/service/hlo_runner_interface.cc
# Saved: third_party/xla/xla/service/hlo_runner_interface.h
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/BUILD
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/functional_hlo_runner.cc
# Saved: third_party/xla/xla/tools/multihost_hlo_runner/functional_hlo_runner.h
# Saved 5 files for PR #87317
# Skipped 0 files
# Files saved to: pr_files/87317_20250307_203054
#
# Retrieving files for PR #87251...
# Saved: third_party/xla/xla/tools/hlo_opt/gpu_specs/README.md
# Saved 1 files for PR #87251
# Skipped 0 files
# Files saved to: pr_files/87251_20250307_203058
#
# Retrieving files for PR #87266...
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/qnn_compiler_plugin_test.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/compiler/qnn_compose_graph.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/dynamic_update_slice_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/dynamic_update_slice_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pack_op_builder.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/builders/pack_op_builder.h
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/BUILD
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.cc
# Saved: tensorflow/lite/experimental/litert/vendors/qualcomm/core/wrappers/quantize_params_wrapper.h
# Saved 11 files for PR #87266
# Skipped 0 files
# Files saved to: pr_files/87266_20250307_203100
#
# Retrieving files for PR #87261...
# Saved: third_party/xla/xla/backends/gpu/runtime/nccl_collective_permute_thunk.cc
# Saved: third_party/xla/xla/backends/gpu/runtime/nccl_collective_permute_thunk.h
# Saved 2 files for PR #87261
# Skipped 0 files
# Files saved to: pr_files/87261_20250307_203107
#
# Retrieving files for PR #87225...
# Saved: third_party/xla/xla/backends/cpu/runtime/convolution_thunk_internal.h
# Saved 1 files for PR #87225
# Skipped 0 files
# Files saved to: pr_files/87225_20250307_203110
#
# Retrieving files for PR #87060...
# Saved: third_party/xla/xla/backends/gpu/codegen/cudnn_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/cudnn_fusion_compiler.cc
# Saved 2 files for PR #87060
# Skipped 0 files
# Files saved to: pr_files/87060_20250307_203111
#
# Retrieving files for PR #87240...
# Saved: third_party/triton/temporary/series.bzl
# Saved: third_party/triton/temporary/sm120.patch
# Saved: third_party/xla/third_party/triton/temporary/series.bzl
# Saved: third_party/xla/third_party/triton/temporary/sm120.patch
# Saved: third_party/xla/xla/backends/gpu/codegen/triton/fusion_emitter.cc
# Saved 5 files for PR #87240
# Skipped 0 files
# Files saved to: pr_files/87240_20250307_203119
#
# Retrieving files for PR #87052...
# Saved: third_party/xla/xla/backends/gpu/codegen/BUILD
# Saved: third_party/xla/xla/backends/gpu/codegen/custom.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/custom.h
# Saved: third_party/xla/xla/backends/gpu/codegen/dynamic_slice_fusion_test.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/fusions.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/fusions.h
# Saved: third_party/xla/xla/backends/gpu/runtime/BUILD
# Saved: third_party/xla/xla/backends/gpu/runtime/dynamic_slice_thunk.cc
# Saved: third_party/xla/xla/service/gpu/ir_emitter_unnested.cc
# Saved: third_party/xla/xla/service/gpu/ir_emitter_unnested.h
# Saved: third_party/xla/xla/service/gpu/transforms/dynamic_slice_fusion_rewriter.cc
# Saved 11 files for PR #87052
# Skipped 0 files
# Files saved to: pr_files/87052_20250307_203123
#
# Retrieving files for PR #87136...
# Saved: third_party/xla/xla/stream_executor/rocm/rocm_executor.cc
# Saved 1 files for PR #87136
# Skipped 0 files
# Files saved to: pr_files/87136_20250307_203131
#
# Retrieving files for PR #87055...
# Saved: third_party/gpus/rocm_configure.bzl
# Saved: third_party/remote_config/common.bzl
# Saved: third_party/xla/third_party/tsl/third_party/gpus/rocm_configure.bzl
# Saved: third_party/xla/third_party/tsl/third_party/remote_config/common.bzl
# Saved 4 files for PR #87055
# Skipped 0 files
# Files saved to: pr_files/87055_20250307_203132
#
# Retrieving files for PR #87056...
# Saved: third_party/gpus/cuda/hermetic/cuda_redist_versions.bzl
# Saved: third_party/xla/third_party/tsl/third_party/gpus/cuda/hermetic/cuda_redist_versions.bzl
# Saved 2 files for PR #87056
# Skipped 0 files
# Files saved to: pr_files/87056_20250307_203136
#
# Retrieving files for PR #87057...
# Saved: third_party/gpus/rocm/BUILD.tpl
# Saved: third_party/xla/third_party/tsl/third_party/gpus/rocm/BUILD.tpl
# Saved 2 files for PR #87057
# Skipped 0 files
# Files saved to: pr_files/87057_20250307_203138
#
# Retrieving files for PR #87121...
# Saved: third_party/xla/xla/service/gpu/transforms/block_scaling_rewriter.cc
# Saved: third_party/xla/xla/service/gpu/transforms/block_scaling_rewriter.h
# Saved: third_party/xla/xla/service/gpu/transforms/block_scaling_rewriter_cudnn_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/cudnn_custom_call_compiler.cc
# Saved 4 files for PR #87121
# Skipped 0 files
# Files saved to: pr_files/87121_20250307_203141
#
# Retrieving files for PR #86555...
# Saved: third_party/xla/xla/backends/gpu/codegen/BUILD
# Saved: third_party/xla/xla/backends/gpu/codegen/custom.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/dynamic_slice_fusion_test.cc
# Saved: third_party/xla/xla/backends/gpu/codegen/fusions.cc
# Saved: third_party/xla/xla/hlo/parser/hlo_parser.cc
# Saved: third_party/xla/xla/hlo/parser/hlo_parser_test.cc
# Saved: third_party/xla/xla/service/gpu/BUILD
# Saved: third_party/xla/xla/service/gpu/gpu_compiler.cc
# Saved: third_party/xla/xla/service/gpu/gpu_compiler_test.cc
# Saved: third_party/xla/xla/service/gpu/ir_emission_utils.cc
# Saved: third_party/xla/xla/service/gpu/ir_emission_utils.h
# Saved: third_party/xla/xla/service/gpu/ir_emitter_unnested.cc
# Saved: third_party/xla/xla/service/gpu/transforms/BUILD
# Saved: third_party/xla/xla/service/gpu/transforms/command_buffer_scheduling.cc
# Saved: third_party/xla/xla/service/gpu/transforms/command_buffer_scheduling_test.cc
# Saved: third_party/xla/xla/service/gpu/transforms/dynamic_slice_fusion_rewriter.cc
# Saved 16 files for PR #86555
# Skipped 0 files
# Files saved to: pr_files/86555_20250307_203145
#
# Processed 78 PRs
# Results saved to pr_files
# Generated solver statistics for 32 contributors
#
# Top Issue Solvers:
# 1. sergachev: 11 issues, 1190 changes
# 2. shraiysh: 10 issues, 2389 changes
# 3. apivovarov: 6 issues, 133 changes
# 4. shawnwang18: 5 issues, 1302 changes
# 5. mmakevic-amd: 4 issues, 77 changes
# 6. hsharsha: 4 issues, 48 changes
# 7. jreiffers: 3 issues, 699 changes
# 8. dependabot[bot]: 3 issues, 8 changes
# 9. yliu120: 3 issues, 31 changes
# 10. tensorflower-gardener: 3 issues, 567 changes
